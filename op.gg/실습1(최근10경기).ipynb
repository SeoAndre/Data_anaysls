# %%
import pandas as pd
import numpy as np
import requests

# %%
api_key='RGAPI-8cdb8cd5-1ad6-4772-931c-021d49eabda7'
summoner_name='내가 잘했구나'

# %%
requesturl='https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/%EB%82%B4%EA%B0%80%20%EC%9E%98%ED%96%88%EA%B5%AC%EB%82%98?api_key=RGAPI-8cdb8cd5-1ad6-4772-931c-021d49eabda7'

# %%
r=requests.get(requesturl)
r.json()
summoner_puuid='gNUeqQ-DC5wXZ9roU1Xb7ZNQqAm72KV0BXRRIXLUL9xWM-fC9yZ-Qvpx30oPjpyfsOSL5MJLvtD6dg'
requesturl='https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/gNUeqQ-DC5wXZ9roU1Xb7ZNQqAm72KV0BXRRIXLUL9xWM-fC9yZ-Qvpx30oPjpyfsOSL5MJLvtD6dg\
/ids?start=0&count=20&api_key=RGAPI-8cdb8cd5-1ad6-4772-931c-021d49eabda7'
r=requests.get(requesturl)
r.json()
# Out:
# ['KR_5505672847',
#  'KR_5505641302',
#  'KR_5505587082',
#  'KR_5505512479',
#  'KR_5505334513',
#  'KR_5502446308',
#  'KR_5502483687',
#  'KR_5502452889',
#  'KR_5502471918',
#  'KR_5502461542',
#  'KR_5452927871',
#  'KR_5452955220',
#  'KR_5443739062',
#  'KR_5443414680',
#  'KR_5443491153',
#  'KR_5443366693',
#  'KR_5413130017',
#  'KR_5412899409',
#  'KR_5412944427',
#  'KR_5412799863']

# %%
matchid="KR_5505672847"

# %%
requesturl='https://asia.api.riotgames.com/lol/match/v5/matches/KR_5505672847?api_key=RGAPI-8cdb8cd5-1ad6-4772-931c-021d49eabda7'
r=requests.get(requesturl)
r.json()
pd.set_option('display.max_columns',None)
r.json()['info']['participants']
df = pd.DataFrame(r.json()['info']['participants'])
df
COLUMNS = ['summonerName','teamId','championName','summoner1Id','summoner2Id','win',
          'item0','item1','item2','item3','item4','item5','item6',
          'kills','deaths','assists','totalDamageDealtToChampions','totalDamageTaken','goldEarned']
df2=df[COLUMNS]
df2
df3=df2.copy()
df3['KDA'] = (df3['kills'] + df3['assists']) / df3['deaths']
df3['GPM'] = df3['goldEarned'] / r.json()['info']['gameDuration'] * 60
df3['DPM'] = df3['totalDamageDealtToChampions'] / r.json()['info']['gameDuration'] * 60
df3['DTPM'] = df3['totalDamageTaken'] / r.json()['info']['gameDuration'] * 60
df3

# %%
Match_01={'DDTC':44087, 'KDA':2.3},{'kindred'}

# %%
matchid='KR_5505641302'

# %%
requesturl='https://asia.api.riotgames.com/lol/match/v5/matches/KR_5505641302?api_key=RGAPI-8cdb8cd5-1ad6-4772-931c-021d49eabda7'
r=requests.get(requesturl)
r.json()
pd.set_option('display.max_columns',None)
r.json()['info']['participants']
df = pd.DataFrame(r.json()['info']['participants'])
df
COLUMNS = ['summonerName','teamId','championName','summoner1Id','summoner2Id','win',
          'item0','item1','item2','item3','item4','item5','item6',
          'kills','deaths','assists','totalDamageDealtToChampions','totalDamageTaken','goldEarned']
df2=df[COLUMNS]
df2
df3=df2.copy()
df3['KDA'] = (df3['kills'] + df3['assists']) / df3['deaths']
df3['GPM'] = df3['goldEarned'] / r.json()['info']['gameDuration'] * 60
df3['DPM'] = df3['totalDamageDealtToChampions'] / r.json()['info']['gameDuration'] * 60
df3['DTPM'] = df3['totalDamageTaken'] / r.json()['info']['gameDuration'] * 60
df3

# %%
Match_2={'DDTC':6714, 'KDA':5.25},{'Blitzcrank'}

# %%
matchid='KR_5505587082'

# %%
requesturl='https://asia.api.riotgames.com/lol/match/v5/matches/KR_5505587082?api_key=RGAPI-8cdb8cd5-1ad6-4772-931c-021d49eabda7'
r=requests.get(requesturl)
r.json()
pd.set_option('display.max_columns',None)
r.json()['info']['participants']
df = pd.DataFrame(r.json()['info']['participants'])
df
COLUMNS = ['summonerName','teamId','championName','summoner1Id','summoner2Id','win',
          'item0','item1','item2','item3','item4','item5','item6',
          'kills','deaths','assists','totalDamageDealtToChampions','totalDamageTaken','goldEarned']
df2=df[COLUMNS]
df2
df3=df2.copy()
df3['KDA'] = (df3['kills'] + df3['assists']) / df3['deaths']
df3['GPM'] = df3['goldEarned'] / r.json()['info']['gameDuration'] * 60
df3['DPM'] = df3['totalDamageDealtToChampions'] / r.json()['info']['gameDuration'] * 60
df3['DTPM'] = df3['totalDamageTaken'] / r.json()['info']['gameDuration'] * 60
df3

# %%
Match_3={'DDTC':1126,'KDA':0.0},{'Graves'}

# %%
matchid='KR_5505512479'

# %%
requesturl='https://asia.api.riotgames.com/lol/match/v5/matches/KR_5505512479?api_key=RGAPI-8cdb8cd5-1ad6-4772-931c-021d49eabda7'
r=requests.get(requesturl)
r.json()
pd.set_option('display.max_columns',None)
r.json()['info']['participants']
df = pd.DataFrame(r.json()['info']['participants'])
df
COLUMNS = ['summonerName','teamId','championName','summoner1Id','summoner2Id','win',
          'item0','item1','item2','item3','item4','item5','item6',
          'kills','deaths','assists','totalDamageDealtToChampions','totalDamageTaken','goldEarned']
df2=df[COLUMNS]
df2
df3=df2.copy()
df3['KDA'] = (df3['kills'] + df3['assists']) / df3['deaths']
df3['GPM'] = df3['goldEarned'] / r.json()['info']['gameDuration'] * 60
df3['DPM'] = df3['totalDamageDealtToChampions'] / r.json()['info']['gameDuration'] * 60
df3['DTPM'] = df3['totalDamageTaken'] / r.json()['info']['gameDuration'] * 60
df3

# %%
Match_4={'DDTC':26302, 'KDA':8},{'LeeSin'}

# %%
matchid='KR_5505334513'

# %%
requesturl='https://asia.api.riotgames.com/lol/match/v5/matches/KR_5505334513?api_key=RGAPI-8cdb8cd5-1ad6-4772-931c-021d49eabda7'
r=requests.get(requesturl)
r.json()
pd.set_option('display.max_columns',None)
r.json()['info']['participants']
df = pd.DataFrame(r.json()['info']['participants'])
df
COLUMNS = ['summonerName','teamId','championName','summoner1Id','summoner2Id','win',
          'item0','item1','item2','item3','item4','item5','item6',
          'kills','deaths','assists','totalDamageDealtToChampions','totalDamageTaken','goldEarned']
df2=df[COLUMNS]
df2
df3=df2.copy()
df3['KDA'] = (df3['kills'] + df3['assists']) / df3['deaths']
df3['GPM'] = df3['goldEarned'] / r.json()['info']['gameDuration'] * 60
df3['DPM'] = df3['totalDamageDealtToChampions'] / r.json()['info']['gameDuration'] * 60
df3['DTPM'] = df3['totalDamageTaken'] / r.json()['info']['gameDuration'] * 60
df3

# %%
Match_5={'DDTC':17942, 'KDA':1.57},{'Khazix'}

# %%
matchid='KR_5502446308'

# %%
requesturl='https://asia.api.riotgames.com/lol/match/v5/matches/KR_5502446308?api_key=RGAPI-8cdb8cd5-1ad6-4772-931c-021d49eabda7'
r=requests.get(requesturl)
r.json()
pd.set_option('display.max_columns',None)
r.json()['info']['participants']
df = pd.DataFrame(r.json()['info']['participants'])
df
COLUMNS = ['summonerName','teamId','championName','summoner1Id','summoner2Id','win',
          'item0','item1','item2','item3','item4','item5','item6',
          'kills','deaths','assists','totalDamageDealtToChampions','totalDamageTaken','goldEarned']
df2=df[COLUMNS]
df2
df3=df2.copy()
df3['KDA'] = (df3['kills'] + df3['assists']) / df3['deaths']
df3['GPM'] = df3['goldEarned'] / r.json()['info']['gameDuration'] * 60
df3['DPM'] = df3['totalDamageDealtToChampions'] / r.json()['info']['gameDuration'] * 60
df3['DTPM'] = df3['totalDamageTaken'] / r.json()['info']['gameDuration'] * 60
df3

# %%
Match_6={'DDTC':13147, 'KDA':1},{'Samira'}

# %%
matchid='KR_5502483687'

# %%
requesturl='https://asia.api.riotgames.com/lol/match/v5/matches/KR_5502483687?api_key=RGAPI-8cdb8cd5-1ad6-4772-931c-021d49eabda7'
r=requests.get(requesturl)
r.json()
pd.set_option('display.max_columns',None)
r.json()['info']['participants']
df = pd.DataFrame(r.json()['info']['participants'])
df
COLUMNS = ['summonerName','teamId','championName','summoner1Id','summoner2Id','win',
          'item0','item1','item2','item3','item4','item5','item6',
          'kills','deaths','assists','totalDamageDealtToChampions','totalDamageTaken','goldEarned']
df2=df[COLUMNS]
df2
df3=df2.copy()
df3['KDA'] = (df3['kills'] + df3['assists']) / df3['deaths']
df3['GPM'] = df3['goldEarned'] / r.json()['info']['gameDuration'] * 60
df3['DPM'] = df3['totalDamageDealtToChampions'] / r.json()['info']['gameDuration'] * 60
df3['DTPM'] = df3['totalDamageTaken'] / r.json()['info']['gameDuration'] * 60
df3

# %%
Match_7={'DDTC':35649, 'KDA':3.75},{'Irelia'}

# %%
matchid='KR_5502452889'

# %%
requesturl='https://asia.api.riotgames.com/lol/match/v5/matches/KR_5502452889?api_key=RGAPI-8cdb8cd5-1ad6-4772-931c-021d49eabda7'
r=requests.get(requesturl)
r.json()
pd.set_option('display.max_columns',None)
r.json()['info']['participants']
df = pd.DataFrame(r.json()['info']['participants'])
df
COLUMNS = ['summonerName','teamId','championName','summoner1Id','summoner2Id','win',
          'item0','item1','item2','item3','item4','item5','item6',
          'kills','deaths','assists','totalDamageDealtToChampions','totalDamageTaken','goldEarned']
df2=df[COLUMNS]
df2
df3=df2.copy()
df3['KDA'] = (df3['kills'] + df3['assists']) / df3['deaths']
df3['GPM'] = df3['goldEarned'] / r.json()['info']['gameDuration'] * 60
df3['DPM'] = df3['totalDamageDealtToChampions'] / r.json()['info']['gameDuration'] * 60
df3['DTPM'] = df3['totalDamageTaken'] / r.json()['info']['gameDuration'] * 60
df3

# %%
Match_8={'DDTC':25381, 'KDA':6.33},{'Jinx'}

# %%
matchid='KR_5502471918'

# %%
requesturl='https://asia.api.riotgames.com/lol/match/v5/matches/KR_5502471918?api_key=RGAPI-8cdb8cd5-1ad6-4772-931c-021d49eabda7'
r=requests.get(requesturl)
r.json()
pd.set_option('display.max_columns',None)
r.json()['info']['participants']
df = pd.DataFrame(r.json()['info']['participants'])
df
COLUMNS = ['summonerName','teamId','championName','summoner1Id','summoner2Id','win',
          'item0','item1','item2','item3','item4','item5','item6',
          'kills','deaths','assists','totalDamageDealtToChampions','totalDamageTaken','goldEarned']
df2=df[COLUMNS]
df2
df3=df2.copy()
df3['KDA'] = (df3['kills'] + df3['assists']) / df3['deaths']
df3['GPM'] = df3['goldEarned'] / r.json()['info']['gameDuration'] * 60
df3['DPM'] = df3['totalDamageDealtToChampions'] / r.json()['info']['gameDuration'] * 60
df3['DTPM'] = df3['totalDamageTaken'] / r.json()['info']['gameDuration'] * 60
df3
# Out:
#   summonerName  teamId championName  summoner1Id  summoner2Id    win  item0  \
# 0   DRX chopaa     100        Sylas           12            4   True   3802
# 1          파크영     100     Nocturne           11            4   True      0
# 2     신천지교주김유성     100         Yone            3            4   True   1055
# 3       내가잘했구나     100       Samira            7            4   True   1055
# 4        Ps 빅벤     100      Alistar           14            4   True   2403
# 5       코 재워줄게     200       Lillia            4           12  False   1082
# 6       순둥이 라면     200          Zac           11            4  False   1039
# 7      양배추재배장인     200          Zed           14            4  False   3142
# 8          혁 켱     200       Lucian           21            4  False   6670
# 9          옥돌이     200       Xerath            7            4  False   2419
#
#    item1  item2  item3  item4  item5  item6  kills  deaths  assists  \
# 0   2033   1026   1001   2010      0   3340      0       2        0
# 1   2031   3051   1001      0      0   3340      0       0        2
# 2   3006   6670   2003      0      0   3340      2       1        1
# 3   6670   1053      0      0      0   3340      4       0        0
# 4   2055   3858   2003   3067   3047   3364      1       1        5
# 5   1001      0   1052      0      0   3340      1       0        1
# 6   2031      0      0      0      0   3340      1       0        0
# 7      0      0      0   1001      0   3340      2       2        0
# 8   2031   1001      0   1055      0   3340      0       2        0
# 9   2003   2010   3851   3802      0   3364      0       4        0
#
#    totalDamageDealtToChampions  totalDamageTaken  goldEarned  KDA         GPM  \
# 0                         1734              3164        3618  0.0  354.127243
# 1                          718              8630        3302  inf  323.197390
# 2                         4479              3660        3286  3.0  321.631321
# 3                         2160              3195        5003  inf  489.690049
# 4                         2204              3944        2935  6.0  287.275693
# 5                         2015              2003        2597  inf  254.192496
# 6                          137              2240        2563  inf  250.864600
# 7                         3312              4379        3397  1.0  332.495922
# 8                         2454              3044        2985  0.0  292.169657
# 9                         2884              4195        2202  0.0  215.530179
#
#           DPM        DTPM
# 0  169.722675  309.690049
# 1   70.277325  844.698206
# 2  438.401305  358.238173
# 3  211.419250  312.724307
# 4  215.725938  386.035889
# 5  197.226754  196.052202
# 6   13.409462  219.249592
# 7  324.176183  428.613377
# 8  240.195759  297.944535
# 9  282.283850  410.603589

# %%
Match_9={'DDTC':2160, 'KDA':4},{'Samira'}

# %%
matchid='KR_5502461542'

# %%
requesturl='https://asia.api.riotgames.com/lol/match/v5/matches/KR_5502461542?api_key=RGAPI-8cdb8cd5-1ad6-4772-931c-021d49eabda7'
r=requests.get(requesturl)
r.json()
pd.set_option('display.max_columns',None)
r.json()['info']['participants']
df = pd.DataFrame(r.json()['info']['participants'])
df
COLUMNS = ['summonerName','teamId','championName','summoner1Id','summoner2Id','win',
          'item0','item1','item2','item3','item4','item5','item6',
          'kills','deaths','assists','totalDamageDealtToChampions','totalDamageTaken','goldEarned']
df2=df[COLUMNS]
df2
df3=df2.copy()
df3['KDA'] = (df3['kills'] + df3['assists']) / df3['deaths']
df3['GPM'] = df3['goldEarned'] / r.json()['info']['gameDuration'] * 60
df3['DPM'] = df3['totalDamageDealtToChampions'] / r.json()['info']['gameDuration'] * 60
df3['DTPM'] = df3['totalDamageTaken'] / r.json()['info']['gameDuration'] * 60
df3
# Out:
#   summonerName  teamId championName  summoner1Id  summoner2Id    win  item0  \
# 0         김무무짱     100       Kennen           12            4   True   3152
# 1          클럽퀸     100     JarvanIV           11            4   True   6630
# 2     보금이전용숟가락     100     Kassadin            4           12   True   1058
# 3       내가잘했구나     100        Xayah            7            4   True   1055
# 4        Ps 빅벤     100      Alistar           14            4   True   3190
# 5         크레토스     200         Sett           12            4  False   3111
# 6       유서스 멀린     200      XinZhao           11            4  False   2055
# 7          낑낑석     200         Ekko            4           12  False   3152
# 8   Ugly Glory     200  MissFortune            7            4  False   2031
# 9      Agriche     200         Rell           14            4  False   3859
#
#    item1  item2  item3  item4  item5  item6  kills  deaths  assists  \
# 0      0   3108   3020   2055   3191   3340      5       4        6
# 1   2031   3047   3044      0   1037   3364      6       1       12
# 2   3110   3070   2033   1082   3020   3364      7       0        2
# 3   6671   3508   1001   1042   2055   3363      7       4        5
# 4   2055   3860   2031   1029   1001   3364      2       4        7
# 5   6630   1028   1036      0      0   3340      3       6        0
# 6   6630   2031   3111   1042   1036   3364      0       5        1
# 7   2033   3020   3057   1052      0   3340      1       6        2
# 8   3006   3134   1037   6672   1055   3340      6       6        2
# 9   3047   3190   2055      0      0   3364      2       4        6
#
#    totalDamageDealtToChampions  totalDamageTaken  goldEarned        KDA  \
# 0                        14941              9484        8346   2.750000
# 1                        11012             15498        8413  18.000000
# 2                         9707              8437        8273        inf
# 3                        11408             10695        8720   3.000000
# 4                         3699              9610        5105   2.250000
# 5                         8704             18364        5642   0.500000
# 6                         4841             17686        5437   0.200000
# 7                         7644             13216        6124   0.500000
# 8                        12532             12447        7694   1.333333
# 9                         6253              9172        4729   2.000000
#
#           GPM         DPM         DTPM
# 0  463.237743  829.287697   526.401480
# 1  466.956522  611.211841   860.203515
# 2  459.185939  538.778908   468.288622
# 3  483.996300  633.191489   593.617021
# 4  283.348751  205.309898   533.395005
# 5  313.154487  483.108233  1019.278446
# 6  301.776133  268.695652   981.646623
# 7  339.907493  424.273821   733.543016
# 8  427.049029  695.578168   690.860315
# 9  262.479186  347.067530   509.084181

# %%
Match_10={'DDTC':11408,'KDA':3},{'Xayah'}
